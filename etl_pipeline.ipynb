# %%
import pandas as pd

# %%
def extract(filepath):
    df = pd.read_csv(filepath)
    return df

# %%
df = extract("sales_raw.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df = extract("sales_raw.csv")
#
# Cell In[4], line 2, in extract(filepath)
#       1 def extract(filepath):
# ----> 2     df = pd.read_csv(filepath)
#       3     return df
#
# File D:\MrinmoyDEN\Data-Pipelines\dev-data-pipes\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File D:\MrinmoyDEN\Data-Pipelines\dev-data-pipes\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File D:\MrinmoyDEN\Data-Pipelines\dev-data-pipes\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File D:\MrinmoyDEN\Data-Pipelines\dev-data-pipes\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File D:\MrinmoyDEN\Data-Pipelines\dev-data-pipes\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sales_raw.csv'

# %%
df

# %%
df = df.dropna(subset=["amount"])
df
# Out:
#    id       date  amount     category region  revenue_after_tax
# 0   1 2024-01-15   250.0  Electronics  North             225.00
# 1   2 2024-01-15   180.5  Electronics  South             162.45
# 2   3 2024-01-15   320.0     Clothing   East             288.00
# 5   6 2024-01-17   410.0     Clothing  North             369.00
# 6   7 2024-01-17    90.0         Food  South              81.00
# 7   8 2024-01-17   130.0         Food   East             117.00
# 9  10 2024-01-18   200.0  Electronics  South             180.00

# %%
df = df[df['amount']>0]

# %%
df['date'] = pd.to_datetime(df['date'], format = 'mixed', dayfirst = True)

# %%
df
# Out:
#    id       date  amount     category region  revenue_after_tax
# 0   1 2024-01-15   250.0  Electronics  North             225.00
# 1   2 2024-01-15   180.5  Electronics  South             162.45
# 2   3 2024-01-15   320.0     Clothing   East             288.00
# 5   6 2024-01-17   410.0     Clothing  North             369.00
# 6   7 2024-01-17    90.0         Food  South              81.00
# 7   8 2024-01-17   130.0         Food   East             117.00
# 9  10 2024-01-18   200.0  Electronics  South             180.00

# %%
df['category'] = df['category'].str.title()

# %%
df
# Out:
#    id       date  amount     category region  revenue_after_tax
# 0   1 2024-01-15   250.0  Electronics  North             225.00
# 1   2 2024-01-15   180.5  Electronics  South             162.45
# 2   3 2024-01-15   320.0     Clothing   East             288.00
# 5   6 2024-01-17   410.0     Clothing  North             369.00
# 6   7 2024-01-17    90.0         Food  South              81.00
# 7   8 2024-01-17   130.0         Food   East             117.00
# 9  10 2024-01-18   200.0  Electronics  South             180.00

# %%
print("Categories:", df["category"].unique())
# Out:
# Categories: <ArrowStringArray>
# ['Electronics', 'Clothing', 'Food']
# Length: 3, dtype: str

# %%
df['revenue_after_tax'] = df['amount'] * 0.9

# %%
df
# Out:
#    id       date  amount     category region  revenue_after_tax
# 0   1 2024-01-15   250.0  Electronics  North             225.00
# 1   2 2024-01-15   180.5  Electronics  South             162.45
# 2   3 2024-01-15   320.0     Clothing   East             288.00
# 5   6 2024-01-17   410.0     Clothing  North             369.00
# 6   7 2024-01-17    90.0         Food  South              81.00
# 7   8 2024-01-17   130.0         Food   East             117.00
# 9  10 2024-01-18   200.0  Electronics  South             180.00

# %%
summary = df.groupby(['category', 'region'])['revenue_after_tax'].sum()
summary
# Out:
# category     region
# Clothing     East      288.00
#              North     369.00
# Electronics  North     225.00
#              South     342.45
# Food         East      117.00
#              South      81.00
# Name: revenue_after_tax, dtype: float64

# %%
df
# Out:
#    id       date  amount     category region  revenue_after_tax
# 0   1 2024-01-15   250.0  Electronics  North             225.00
# 1   2 2024-01-15   180.5  Electronics  South             162.45
# 2   3 2024-01-15   320.0     Clothing   East             288.00
# 5   6 2024-01-17   410.0     Clothing  North             369.00
# 6   7 2024-01-17    90.0         Food  South              81.00
# 7   8 2024-01-17   130.0         Food   East             117.00
# 9  10 2024-01-18   200.0  Electronics  South             180.00
